# %%
import warnings
import sys
from pyscf import data

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import h5py
from atom_rdf_pack.atom_rdf import get_rmsd_error, rad
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', None)

# %%
atom_config = ["B+1", "B+3", "C+2", "C+4", "N+3", "N+5", "O+4", "O+6", "F+5", "F+7", "Ne+0", "Ne+6", "Ne+8"]
atom_config_with_be = atom_config + ["Be+0"]

# %%
atom_cfg = [(l, l.split("+")[0], int(l.split("+")[1])) for l in atom_config]
atom_cfg_with_be = [(l, l.split("+")[0], int(l.split("+")[1])) for l in atom_config_with_be]

# %%
def h5group_to_dict(grp):
    dct = {}
    for key, val in grp.items():
        if isinstance(val, h5py.Dataset):
            dct[key] = val[()]
        else:
            dct[key] = h5group_to_dict(val)
    return dct

# %%
def get_rdf_error(dct1, dct2):
    return pd.Series({key: get_rmsd_error(dct1[key], dct2[key], scale=key) for key in ["RHO", "GRD", "LR"]}) / data.nist.BOHR

# %% [markdown]
# ## Load Data

# %%
# %%time
with h5py.File(f"rdf.h5", "r") as f:
    dict_ref = h5group_to_dict(f["CCSD"]["aug-cc-pwcv5z"])
# Out:
# CPU times: user 1.64 ms, sys: 12.9 ms, total: 14.6 ms
# Wall time: 32.4 ms

# %%
# %%time
with h5py.File(f"rdf-low.h5", "r") as f:
    dict_low = h5group_to_dict(f)
# Out:
# CPU times: user 1.48 s, sys: 1.59 s, total: 3.07 s
# Wall time: 6.74 s

# %%
# %%time
with h5py.File(f"rdf-dh.h5", "r") as f:
    dict_dh = h5group_to_dict(f)
# Out:
# CPU times: user 416 ms, sys: 536 ms, total: 952 ms
# Wall time: 2.12 s

# %% [markdown]
# ## RDF Error analysis

# %%
def get_tab_err(dat, ref):
    dct = {}
    for atom in atom_config_with_be:
        dct[atom] = get_rdf_error(dat[atom], ref[atom])
    return pd.DataFrame(dct)

# %%
column = pd.MultiIndex.from_tuples([(task, atom) for task in ["RHO", "GRD", "LR"] for atom in atom_config_with_be])

# %%
# %%time
dct = {}
column = pd.MultiIndex.from_tuples([(task, atom) for task in ["RHO", "GRD", "LR"] for atom in atom_config_with_be])
for xc in dict_low:
    err = get_tab_err(dict_low[xc]["aug-cc-pwcv5z"], dict_ref)
    dct[xc] = pd.Series(np.array(err).reshape(-1), index=column)
tab_full_low = pd.DataFrame(dct).T
tab_full_low.to_csv("Table-RDF-low.csv")
# Out:
# CPU times: user 397 ms, sys: 1.96 ms, total: 399 ms
# Wall time: 401 ms

# %%
# %%time
dct = {}
column = pd.MultiIndex.from_tuples([(task, atom) for task in ["RHO", "GRD", "LR"] for atom in atom_config_with_be])
for xc in dict_low:
    err = get_tab_err(dict_low[xc]["aug-cc-pv5z"], dict_ref)
    dct[xc] = pd.Series(np.array(err).reshape(-1), index=column)
tab_full_pv5z_low = pd.DataFrame(dct).T
tab_full_pv5z_low.to_csv("Table-RDF-low-pv5z.csv")
# Out:
# CPU times: user 398 ms, sys: 825 µs, total: 399 ms
# Wall time: 401 ms

# %%
pd.DataFrame({
    "RHO": tab_full_low["RHO"].T.max(),
    "GRD": tab_full_low["GRD"].T.max(),
    "LR": tab_full_low["LR"].T.max(),
})
# Out:
#                      RHO          GRD            LR
# APFD            1.666953     1.780747      1.812968
# B1B95           1.618496     1.942107      2.033329
# B3LYP           2.122773     1.712187      1.905967
# B3LYP*          2.445838     1.706096      1.823662
# B3LYPV1R        2.108666     1.713396      1.907803
# B3P86           1.701735     1.871877      1.936202
# B3PW91          1.651938     1.756371      1.813514
# B97-1           1.721124     1.961903      1.942481
# B97-2           1.911641     2.017747      1.596285
# B97-3           1.623921     1.846970      1.879701
# B97-K           1.585516     2.281506      2.842566
# BC              3.440767     2.137787      1.541429
# BHHLYP          1.683919     1.699923      1.512152
# BLYP            3.458304     2.049877      2.454590
# BMK             1.697379     1.913603      3.089677
# BOP             2.908702     1.946238      2.409713
# BP86            2.474341     2.096090      2.469872
# BPBE            2.240239     1.942421      2.282808
# BPW91           2.329752     1.956081      2.328660
# BPZ81           2.955854     2.086840      2.607753
# BVWN            2.928664     2.085574      2.606501
# BVWN1RPA        2.869572     2.093730      2.615991
# Becke           3.716001     2.001388      2.425778
# CAM-B3LYP       2.342887     1.832123      2.103398
# CASE21          1.632295     1.820855      1.912945
# EDF1            2.098647     1.990519      2.032306
# GAS22           2.037272     2.507136      2.388464
# GLYP          456.660549  2948.360166   6296.573056
# GOP           161.155522   317.818322    259.465931
# GP86          147.666198   244.645509    709.824327
# GPBE         1081.874051   737.375520    451.759012
# GPW91        1630.691575  1184.861482    831.633565
# GPZ81         163.674147   330.426442    545.857985
# GVWN          161.583674   331.948759    297.387900
# GVWN1RPA      441.574472  2936.845712   6333.302050
# Gill          147.928477   244.660157    140.160697
# HCTH407         2.160802     1.743407      1.077082
# HSE06           1.673234     1.829285      1.983530
# LYP             2.786136     2.021357      1.496472
# M05             1.728544     2.744559      5.766840
# M05-2X          2.677252     2.318220      3.739927
# M06             1.837464     2.260926      3.682377
# M06-2X          1.496396     2.139377      4.213742
# M06-HF          5.891136     4.477818      5.136204
# M06-L           2.355789     2.383617      2.729816
# M06-SX          1.700071     2.434384      3.616853
# M08-HX          2.661467     2.549587      3.699659
# M08-SO          2.669912     2.840277      4.783833
# M11             4.413576     3.251992      5.613752
# M11-L           6.829600     8.469957     16.267592
# MN12-L          3.908232     4.985548      8.994762
# MN12-SX         3.416760     4.575304     13.004112
# MN15            5.251814    10.331247     23.795075
# MN15-L          3.857492     8.511484     21.819811
# MOHLYP          2.246235     1.551800      1.231425
# MS0             2.035997     2.131440      1.890022
# MS1             2.030364     2.153093      1.963346
# MS2             1.927827     2.124594      1.997120
# MVS          1191.355518  4542.487019  14937.519868
# N12             6.308472     6.386859      6.708958
# N12-SX          5.012512     6.325770      6.970042
# O3LYP           1.818097     1.946528      1.615747
# OLYP            1.901766     2.119410      1.853914
# OP              3.628410     2.123064      1.492835
# OP86            2.106695     2.379118      1.953265
# OPBE            2.067200     2.234927      1.760561
# OPTX            1.960867     2.146837      1.820515
# OPW91           2.042132     2.236554      1.794205
# OPZ81           1.896073     2.308341      2.044199
# OVWN            1.894079     2.307402      2.043058
# OVWN1RPA        1.921381     2.316501      2.054898
# P86             3.650009     2.293808      1.659003
# PBE             2.493444     1.826084      2.170299
# PBE0            1.678313     1.798872      1.816052
# PBE1KCIS        1.572311     1.791599      1.954166
# PBEC            3.899421     2.141230      1.478768
# PBELYP          3.706911     1.992025      2.347583
# PBELYP1w        3.546018     1.965456      2.384832
# PBEOP           3.141313     1.871150      2.297964
# PBEP86          2.734962     1.970774      2.352883
# PBEPW91         2.574724     1.839828      2.216024
# PBEPZ81         3.164462     1.969935      2.495304
# PBEVWN          3.134780     1.968633      2.494042
# PBEX            3.992314     1.955605      2.317501
# PBEh1PBE        1.674473     1.829958      1.983383
# PBEsol          2.633689     2.179960      1.893537
# PKZB            2.025002     2.166416      1.984596
# PW91            2.642341     1.870093      2.285054
# PW91C           3.827093     2.140429      1.497412
# PW91LYP         3.763419     2.135279      2.415552
# PW91P86         2.781151     2.004451      2.422514
# PW91PBE         2.554321     1.855502      2.239083
# PW91PZ81        3.262575     2.064338      2.564067
# PW91VWN         3.235352     2.061801      2.562821
# PW91X           4.015004     2.084667      2.386124
# PZ81            3.494539     2.204207      1.695531
# R2SCAN          2.099095     2.098821      1.851234
# R2SCAN0         2.058658     2.058929      1.688668
# R2SCAN50        2.020525     2.033332      1.564475
# R4SCAN          2.076695     2.112000      1.879245
# R4SCAN0         2.042890     2.068911      1.709765
# RPBE            2.139806     2.152728      2.451630
# RSCAN           2.048659     2.085532      1.859857
# SCAN          242.440485   762.373202   1359.905514
# SLYP            4.428321     4.179517      3.496639
# SOGGA           2.554277     2.122159      1.879474
# SOGGA11         4.970632     3.668868      3.792317
# SOGGA11X        1.539616     2.237601      2.841523
# SOP             3.691496     4.037632      3.487322
# SP86            3.708822     3.820440      3.277497
# SPBE            3.461177     3.976629      3.480998
# SPW91           3.499653     3.987879      3.474327
# SPZ81           3.764322     3.983683      3.345802
# SVWN            3.725131     3.983244      3.349078
# SVWN1RPA        3.631283     3.975936      3.345895
# Slater          4.864004     4.173125      3.473472
# Slater, P86     3.708849     3.820426      3.277486
# TPSS            1.948065     2.042918      1.637535
# TPSSLYP1w       2.934510     2.010567      1.773180
# TPSSh           1.902901     2.045458      1.604696
# TPSSm           1.910843     2.080105      1.657060
# VWN1RPA         3.650341     2.210774      1.707110
# VWN5            3.539821     2.202568      1.694459
# X3LYP           2.083416     1.701380      1.884925
# XAlpha         23.605680    14.530870     11.781014
# mPW1LYP         1.992919     1.840526      2.068790
# mPW1PBE         1.698811     1.876989      1.910399
# mPW1PW91        1.674900     1.887651      1.955072
# mPW3PBE         1.623735     1.733588      1.814422
# mPWLYP1w        3.529048     2.083130      2.479627
# mPWPBE          2.384987     1.916163      2.287836
# r++SCAN         2.055890     2.086279      1.856771
# revB3LYP        2.166964     1.599496      1.738362
# revM06          1.504758     2.001711      3.035836
# revM06-L        2.388928     2.319240      3.781974
# revM11          3.787097     3.771830      7.531984
# revPBE          2.103278     2.074198      2.369578
# revSCAN       159.052068   293.921514   1027.784941
# revSCAN0      167.807104   340.502393    268.799617
# revTPSS         1.968927     2.048763      1.585362
# τHCTH           2.220002     2.085429      2.054957
# τHCTHhyb        1.859882     1.837065      1.882493
# ωB97            2.310667     2.833088      2.837862
# ωB97X           2.075066     2.415441      2.489615

# %%
# %%time
dct = {}
column = pd.MultiIndex.from_tuples([(task, atom) for task in ["RHO", "GRD", "LR"] for atom in atom_config_with_be])
for xc in dict_dh:
    err = get_tab_err(dict_dh[xc]["aug-cc-pwcv5z"], dict_ref)
    dct[xc] = pd.Series(np.array(err).reshape(-1), index=column)
tab_full_dh = pd.DataFrame(dct).T
tab_full_dh.to_csv("Table-RDF-dh.csv")
# Out:
# CPU times: user 133 ms, sys: 569 µs, total: 134 ms
# Wall time: 135 ms

# %%
# %%time
dct = {}
column = pd.MultiIndex.from_tuples([(task, atom) for task in ["RHO", "GRD", "LR"] for atom in atom_config_with_be])
for xc in dict_dh:
    err = get_tab_err(dict_dh[xc]["aug-cc-pv5z"], dict_ref)
    dct[xc] = pd.Series(np.array(err).reshape(-1), index=column)
tab_full_dh_pv5z = pd.DataFrame(dct).T
tab_full_dh_pv5z.to_csv("Table-RDF-dh-pv5z.csv")
# Out:
# CPU times: user 129 ms, sys: 5.15 ms, total: 134 ms
# Wall time: 135 ms

# %%
pd.DataFrame({
    "RHO": tab_full_dh["RHO"].T.max(),
    "GRD": tab_full_dh["GRD"].T.max(),
    "LR" : tab_full_dh["LR" ].T.max(),
})
# Out:
#                        RHO       GRD        LR
# B2GP_PLYP         1.442336  1.570672  1.405187
# B2GP_PLYP_D3BJ    1.442336  1.583475  1.396060
# B2PLYP            1.408461  1.575831  1.541530
# DSD_BLYP_D3BJ     1.413456  1.530166  1.319359
# DSD_PBEB95_D3BJ   1.367139  1.503894  1.313250
# DSD_PBEP86_D3BJ   1.432707  1.539768  1.302873
# DSD_PBEPBE_D3BJ   1.379039  1.437469  1.193828
# LS1DH_PBE         1.572222  1.614176  1.241276
# PBE0_2            1.550024  1.597471  1.210851
# PBE0_DH           1.651873  1.700858  1.479808
# PBE_CIDH          1.638177  1.680817  1.422126
# PBE_QIDH          1.597371  1.635134  1.285976
# PTPSS_D3Zero      1.315985  1.530805  1.572753
# PWPB95_D3Zero     1.368591  1.630877  1.627658
# RSX_0DH           1.707731  1.675547  1.411364
# RSX_QIDH          1.637487  1.639544  1.268919
# RS_B88_LYP        1.492577  1.577231  1.516161
# RS_PBE_P86        1.581410  1.648036  1.496640
# RS_PBE_PBE        1.556841  1.540027  1.349243
# RS_PW91_PW91      1.538923  1.568743  1.416878
# SOS0_PBE0_DH      1.604554  1.657178  1.453849
# SOS0_PBE_QIDH     1.505269  1.551432  1.233674
# SOS_RSX_PBE0_DH   1.670627  1.643506  1.393547
# SOS_RSX_PBE_QIDH  1.551670  1.564230  1.223274
# TPSS0_DH          1.829574  1.919073  1.412821
# TPSS_CIDH         1.799235  1.885301  1.381649
# TPSS_QIDH         1.708580  1.789185  1.299129
# XYG3              1.143714  1.220508  1.030810
# XYG5              0.923516  0.802816  0.519950
# XYG6              0.901323  0.665436  0.444908
# XYG7              1.586041  1.463042  1.377048
# XYGJ_OS           0.907952  0.733366  0.674218
# XYGJ_OS5          0.771090  0.995833  1.032277
# lrc_XYG3          1.143715  1.220497  1.030798
# mPW2PLYP          1.436812  1.592013  1.535806
# revPBE0_DH        1.722596  1.892413  1.660362
# revXYG3           1.047561  1.112786  0.876250
# revXYGJ_OS        0.712013  0.499853  0.320192
# wB2GP_PLYP        1.489516  1.573007  1.384653
# wB2PLYP           1.479238  1.574076  1.504179
# wB88PP86          1.544952  1.674145  1.422085
# wB97X_2_LP        2.144335  1.795660  2.251929
# wB97X_2_TQZ       1.694312  1.817643  1.940511
# wPBEPP86          1.532423  1.647887  1.351731
# xDH_PBE0          0.906552  0.897644  0.668525

# %% [markdown]
# ## Energy Analysis

# %%
# %%time
with h5py.File(f"etot-low.h5", "r") as f:
    dict_eng_low = h5group_to_dict(f)
# Out:
# CPU times: user 408 ms, sys: 216 ms, total: 624 ms
# Wall time: 1.24 s

# %%
# %%time
dct = {}
for xc in dict_eng_low:
    dct[xc] = dict_eng_low[xc]["aug-cc-pwcv5z"]
pd.DataFrame(dct).T.to_csv("Table-etot-low.csv")
# Out:
# CPU times: user 4.94 ms, sys: 0 ns, total: 4.94 ms
# Wall time: 6.41 ms

# %%
# %%time
dct = {}
for xc in dict_eng_low:
    dct[xc] = dict_eng_low[xc]["aug-cc-pv5z"]
pd.DataFrame(dct).T.to_csv("Table-etot-low-pv5z.csv")
# Out:
# CPU times: user 4.45 ms, sys: 0 ns, total: 4.45 ms
# Wall time: 5.89 ms

# %%
# %%time
with h5py.File(f"etot-dh.h5", "r") as f:
    dict_eng_dh = h5group_to_dict(f)
# Out:
# CPU times: user 133 ms, sys: 69.3 ms, total: 202 ms
# Wall time: 398 ms

# %%
# %%time
dct = {}
for xc in dict_eng_dh:
    dct[xc] = dict_eng_dh[xc]["aug-cc-pwcv5z"]
pd.DataFrame(dct).T.to_csv("Table-etot-dh.csv")
# Out:
# CPU times: user 1.37 ms, sys: 1.27 ms, total: 2.64 ms
# Wall time: 3.93 ms

# %%
# %%time
dct = {}
for xc in dict_eng_dh:
    dct[xc] = dict_eng_dh[xc]["aug-cc-pv5z"]
pd.DataFrame(dct).T.to_csv("Table-etot-dh-pv5z.csv")
# Out:
# CPU times: user 1.55 ms, sys: 1.44 ms, total: 2.99 ms
# Wall time: 4.1 ms

# %% [markdown]
# ## Auxiliary

# %%
# %%time
with h5py.File(f"conv-low.h5", "r") as f:
    dict_conv = h5group_to_dict(f)
# Out:
# CPU times: user 401 ms, sys: 224 ms, total: 625 ms
# Wall time: 1.2 s

# %%
for method in dict_conv:
    for basis in dict_conv[method]:
        for atom in dict_conv[method][basis]:
            if not dict_conv[method][basis][atom]:
                print(method, basis, atom)
# Out:
# GLYP aug-cc-pv5z C+4
# GLYP aug-cc-pwcv5z B+3
# GLYP aug-cc-pwcv5z N+5
# GLYP aug-cc-pwcv5z Ne+8
# GLYP aug-cc-pwcv5z O+6
# GOP aug-cc-pv5z C+4
# GOP aug-cc-pv5z Ne+8
# GOP aug-cc-pwcv5z N+5
# GOP aug-cc-pwcv5z Ne+8
# GOP aug-cc-pwcv5z O+6
# GP86 aug-cc-pv5z Ne+8
# GP86 aug-cc-pwcv5z N+5
# GP86 aug-cc-pwcv5z Ne+8
# GP86 aug-cc-pwcv5z O+6
# GPBE aug-cc-pv5z Ne+8
# GPBE aug-cc-pwcv5z F+7
# GPBE aug-cc-pwcv5z N+5
# GPBE aug-cc-pwcv5z Ne+8
# GPBE aug-cc-pwcv5z O+6
# GPW91 aug-cc-pv5z Ne+8
# GPW91 aug-cc-pwcv5z F+7
# GPW91 aug-cc-pwcv5z N+5
# GPW91 aug-cc-pwcv5z Ne+8
# GPW91 aug-cc-pwcv5z O+6
# GPZ81 aug-cc-pv5z C+4
# GPZ81 aug-cc-pv5z Ne+8
# GPZ81 aug-cc-pwcv5z B+1
# GPZ81 aug-cc-pwcv5z N+5
# GPZ81 aug-cc-pwcv5z Ne+8
# GPZ81 aug-cc-pwcv5z O+6
# GVWN aug-cc-pv5z C+4
# GVWN aug-cc-pv5z Ne+8
# GVWN aug-cc-pwcv5z B+1
# GVWN aug-cc-pwcv5z N+5
# GVWN aug-cc-pwcv5z Ne+8
# GVWN aug-cc-pwcv5z O+6
# GVWN1RPA aug-cc-pv5z C+4
# GVWN1RPA aug-cc-pv5z Ne+8
# GVWN1RPA aug-cc-pwcv5z B+1
# GVWN1RPA aug-cc-pwcv5z B+3
# GVWN1RPA aug-cc-pwcv5z N+5
# GVWN1RPA aug-cc-pwcv5z Ne+8
# GVWN1RPA aug-cc-pwcv5z O+6
# Gill aug-cc-pv5z Be+0
# Gill aug-cc-pv5z C+4
# Gill aug-cc-pv5z Ne+8
# Gill aug-cc-pwcv5z N+5
# Gill aug-cc-pwcv5z O+6
# MVS aug-cc-pv5z B+3
# MVS aug-cc-pv5z C+4
# MVS aug-cc-pv5z F+7
# MVS aug-cc-pv5z N+5
# MVS aug-cc-pv5z Ne+8
# MVS aug-cc-pv5z O+6
# MVS aug-cc-pwcv5z B+3
# MVS aug-cc-pwcv5z C+4
# MVS aug-cc-pwcv5z F+7
# MVS aug-cc-pwcv5z N+5
# MVS aug-cc-pwcv5z Ne+8
# MVS aug-cc-pwcv5z O+6
# SCAN aug-cc-pv5z B+3
# SCAN aug-cc-pv5z C+4
# SCAN aug-cc-pv5z N+5
# SCAN aug-cc-pv5z Ne+8
# SCAN aug-cc-pwcv5z B+3
# SCAN aug-cc-pwcv5z C+4
# SCAN aug-cc-pwcv5z F+7
# SCAN aug-cc-pwcv5z N+5
# SCAN aug-cc-pwcv5z Ne+8
# revSCAN aug-cc-pv5z B+3
# revSCAN aug-cc-pv5z C+4
# revSCAN aug-cc-pv5z F+7
# revSCAN aug-cc-pv5z N+5
# revSCAN aug-cc-pv5z Ne+8
# revSCAN aug-cc-pv5z O+6
# revSCAN aug-cc-pwcv5z B+3
# revSCAN aug-cc-pwcv5z C+4
# revSCAN aug-cc-pwcv5z F+7
# revSCAN aug-cc-pwcv5z N+5
# revSCAN aug-cc-pwcv5z Ne+8
# revSCAN aug-cc-pwcv5z O+6
# revSCAN0 aug-cc-pv5z B+3
# revSCAN0 aug-cc-pv5z C+4
# revSCAN0 aug-cc-pv5z F+7
# revSCAN0 aug-cc-pv5z N+5
# revSCAN0 aug-cc-pv5z Ne+8
# revSCAN0 aug-cc-pv5z O+6
# revSCAN0 aug-cc-pwcv5z B+3
# revSCAN0 aug-cc-pwcv5z C+4
# revSCAN0 aug-cc-pwcv5z F+7
# revSCAN0 aug-cc-pwcv5z N+5
# revSCAN0 aug-cc-pwcv5z Ne+8
# revSCAN0 aug-cc-pwcv5z O+6
